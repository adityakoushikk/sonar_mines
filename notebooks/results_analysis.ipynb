# %% [markdown]
# # Results analysis
#
# Purpose: pull metrics from completed runs and compare ablations.
#
# TODO:
# - Pull metrics for A0–A5 (augmentation ablation) from W&B.
# - Pull metrics for B1–B5 (init ablation) from W&B.
# - Plot mAP50 / mAP50-95 vs. ablation with per-seed error bars.
# - Run paired significance tests between adjacent ablations.
# - Compare YOLO best variant against the HOG+SVM classical baseline.
