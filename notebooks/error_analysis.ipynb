# %% [markdown]
# # Error analysis
#
# Purpose: dig into what the best model gets wrong.
#
# TODO:
# - Load the best checkpoint and run inference on the held-out test split.
# - Bucket errors: missed detections, false positives, class confusions.
# - Show worst-mAP images with overlaid predictions vs. ground truth.
# - Slice errors by class (MILCO vs. NOMBO), bbox size, and image intensity.
# - Check whether failure modes correlate with sonar-physics characteristics
#   (range falloff, shadow visibility, speckle SNR).
